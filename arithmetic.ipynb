# %%
# Exponentiation
exponential:int = 2 ** 10
print("2 ** 10 = ", exponential)

# Floor division
floor_division = 12//5
print("12 // 5 = ", floor_division)

#Standard division
std_division = 12/5
print("12 / 7 = ", std_division)

# Remainder
modulus = 12%7
print("12 % 7 = ", modulus)
# Out:
# 2 ** 10 =  1024
# 12 // 5 =  2
# 12 / 7 =  2.4
# 12 % 7 =  5
