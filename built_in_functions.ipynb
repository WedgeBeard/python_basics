# %%
# BIFs (Built in Functions)

# Min/Max - return minimum or maximum number in a collection
collection1 = [12, 33, 82, 666, -34]
print("Min: ", min(collection1))
print("Max: ", max(collection1))

# len - returns length (count) of items in a collection
print(len(collection1))
# Out:
# Min:  -34
# Max:  666
# 5
