# %%
#==================================
#============ FUNCTIONS ===========
#==================================
def square(number):
    """Calculates the square of a number.""" # doc string for IDE to show when using
    return number ** 2

print(square(8))
# Out:
# 64
