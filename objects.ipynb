# %%
#==================================
#============ OBJECTS =============
#==================================

# find the attributes of an object
# print dir combo mambo:
my_string = "blarg"
dir(my_string)
