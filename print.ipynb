# %%
#==================================
#========== BASIC PRINT ===========
#==================================
# \n <-new line
print("This inserts a new line \nwherever it goes\n")

# \t <- horizontal tab
print("Insert a horizontal tab \t where you want.")

# \\ <- instert backslash in a string
print("Insert a \\ backslash somewhere \\ and again.")

# \" <- insert a double quote in a string
print("Insert a double quote when speaking, \"Which way to Python-land?\"")

# \' <- insert a stingle quote in a string
print("Insert a single quote; Well \'ello Gov\'na\'!")

# super long strings, wrap in IDE
print("When a string gets to be too long for the IDE, " \
"you can split it across multiple lines " \
"by using this method")

# multi-line strings - triple quoted
print("""\nSometime's you just need to do things
   "without" all the escape characters!
       That's where the triple-quotes come in handy.
          They also retain indentation and layout.""")


#==================================
#========== PRINT FORMAT ==========
#==================================
some_amount = 12.410988409809710983
print(f'{some_amount:8f}')
# Out:
# This inserts a new line
# wherever it goes
#
# Insert a horizontal tab 	 where you want.
# Insert a \ backslash somewhere \ and again.
# Insert a double quote when speaking, "Which way to Python-land?"
# Insert a single quote; Well 'ello Gov'na'!
# When a string gets to be too long for the IDE, you can split it across multiple lines by using this method
#
# Sometime's you just need to do things
#    "without" all the escape characters!
#        That's where the triple-quotes come in handy.
#           They also retain indentation and layout.
# 12.410988

# %%
# get user input
name = input("What's your name, person?")
print("Huh, they call you ", name, ", right?")
